# %%
import pandas as pd, seaborn as sns, numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_excel("titanic3 (3).xls")
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data.shape
data.columns
data_reduce = data.drop(["name","sibsp","parch","ticket","fare","cabin","embarked","boat","body","home.dest"],axis =1)

# %%
data_reduce.head()
# Out:
#    pclass  survived     sex      age
# 0       1         1  female  29.0000
# 1       1         1    male   0.9167
# 2       1         0  female   2.0000
# 3       1         0    male  30.0000
# 4       1         0  female  25.0000

# %%
data_reduce.describe()
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
data_reduce=data_reduce.dropna(axis=0)
data_reduce.describe()
# Out:
#             pclass     survived          age
# count  1046.000000  1046.000000  1046.000000
# mean      2.207457     0.408222    29.881135
# std       0.841497     0.491740    14.413500
# min       1.000000     0.000000     0.166700
# 25%       1.000000     0.000000    21.000000
# 50%       2.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
sns.set_theme()
data_reduce["pclass"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data_reduce["age"].hist(bins=25)
# Out:
# <AxesSubplot:>

# %%
data_reduce.groupby(["sex"]).mean()
# Out:
#         pclass  survived        age
# sex
# male  2.207457  0.408222  29.881135

# %%
data_reduce.groupby(["sex","pclass"]).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.965278  37.037594
#        2       0.886792  27.499191
#        3       0.490741  22.185307
# male   1       0.340782  41.029250
#        2       0.146199  30.815401
#        3       0.152130  25.962273

# %%
p= data_reduce[data_reduce["age"]<18]
p["sex"].value_counts()
r = data_reduce[:10]
r["age"]
data_reduce[["sex","age"]].head()
data_reduce[data_reduce["age"]<18].groupby(["sex","pclass"]).mean()
# Out:
#                survived        age
# sex    pclass
# female 1       0.875000  14.125000
#        2       1.000000   8.273150
#        3       0.543478   8.416667
# male   1       0.857143   9.845243
#        2       0.733333   6.222220
#        3       0.233333   9.838888

# %%
data_reduce["age"][:10]
# Out:
# 0    29.0000
# 1     0.9167
# 2     2.0000
# 3    30.0000
# 4    25.0000
# 5    48.0000
# 6    63.0000
# 7    39.0000
# 8    53.0000
# 9    71.0000
# Name: age, dtype: float64

# %%
data_reduce.iloc[0:4,2:4]
data_reduce.iloc[2,2]
# Out:
# 'female'

# %%
categorie_1=data_reduce[data_reduce["age"]<20]
categorie_2= data_reduce[(data_reduce["age"]>=30) & (data_reduce["age"]<=20)]
categorie_1.loc[:,["sex","age"]]
# Out:
#          sex      age
# 1       male   0.9167
# 2     female   2.0000
# 11    female  18.0000
# 27    female  19.0000
# 53      male  17.0000
# ...      ...      ...
# 1275    male  16.0000
# 1279  female  14.0000
# 1288    male  18.0000
# 1300  female  15.0000
# 1304  female  14.5000
#
# [225 rows x 2 columns]
